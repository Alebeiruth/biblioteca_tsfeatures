# %% [markdown]
# <a href="https://colab.research.google.com/github/Alebeiruth/biblioteca_tsfeatures/blob/main/tsfeatures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tsfeatures

# %%
import os
import subprocess
import urllib
import numpy as np
import pandas as pd

# %%
from tsfeatures import tsfeatures

# %%
df = pd.read_csv("/content/painel.txt", sep=",")
print(df.head())
print(df.columns)
# Out:
#   unique_id          ds       y
# 0        D1  1972-09-28  2015.6
# 1        D1  1972-09-29  2009.7
# 2        D1  1972-09-30  2022.1
# 3        D1  1972-10-01  2031.6
# 4        D1  1972-10-02  2029.7
# Index(['unique_id', 'ds', 'y'], dtype='object')

# %%
df.head()
# Out:
#   unique_id          ds       y
# 0        D1  1972-09-28  2015.6
# 1        D1  1972-09-29  2009.7
# 2        D1  1972-09-30  2022.1
# 3        D1  1972-10-01  2031.6
# 4        D1  1972-10-02  2029.7

# %%
df.describe()
# Out:
#                 y
# count    10.00000
# mean   2326.31000
# std     321.19548
# min    2009.70000
# 25%    2024.00000
# 50%    2325.85000
# 75%    2628.65000
# max    2649.30000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   unique_id  10 non-null     object
#  1   ds         10 non-null     object
#  2   y          10 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 368.0+ bytes

# %%
tsfeatures(df, freq=7)
# Out:
#   unique_id     hurst  series_length  unitroot_pp  unitroot_kpss  hw_alpha  \
# 0        D1  0.869858              5    -1.335069       0.302678       NaN
# 1       D10  0.676865              5    -3.109388       0.262029       NaN
#
#    hw_beta  hw_gamma  stability  nperiods  ...   entropy  crossing_points  \
# 0      NaN       NaN          0         1  ...  0.045634                1
# 1      NaN       NaN          0         1  ...  0.314663                2
#
#    arch_lm    x_acf1  x_acf10  diff1_acf1  diff1_acf10  diff2_acf1  \
# 0      NaN  0.441581      NaN         NaN          NaN         NaN
# 1      NaN  0.182788      NaN         NaN          NaN         NaN
#
#    diff2_acf10  seas_acf1
# 0          NaN        NaN
# 1          NaN        NaN
#
# [2 rows x 43 columns]

# %%
tsfeatures(df, freq=1)
# Out:
#   unique_id     hurst  series_length  unitroot_pp  unitroot_kpss  hw_alpha  \
# 0        D1  0.869858              5    -1.335069       0.302678       NaN
# 1       D10  0.676865              5    -3.109388       0.262029       NaN
#
#    hw_beta  hw_gamma  stability  nperiods  ...  flat_spots   entropy  \
# 0      NaN       NaN          0         0  ...           2  0.045634
# 1      NaN       NaN          0         0  ...           2  0.314663
#
#    crossing_points  arch_lm    x_acf1  x_acf10  diff1_acf1  diff1_acf10  \
# 0                1      NaN  0.441581      NaN         NaN          NaN
# 1                2      NaN  0.182788      NaN         NaN          NaN
#
#    diff2_acf1  diff2_acf10
# 0         NaN          NaN
# 1         NaN          NaN
#
# [2 rows x 38 columns]

# %% [markdown]
# **hust** > indica o nível de diferenciação
# fracionária de uma série temporal.
#
# **uniitroot_pp** > estatística para a versão ''Z-alpha'' do teste de raiz unitária de Phillips & Perron com tendência constante e atraso 1.
#
# **uniitroot_kpss** > estatística para Kwiatkowski et al. teste de raiz unitária com tendência linear e defasagem 1.
#
# **flat_spot** > O número de pontos planos na série, calculado discretizando a série em 10 intervalos de tamanhos iguais e contando a duração máxima da execução dentro de qualquer intervalo único.
#
# **x_acf1** >  primeiro coeficiente de autocorrelação da série.
# crossing_points > número de vezes que a série temporal cruza a mediana
